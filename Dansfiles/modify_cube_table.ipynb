# %%
from mstr_robotics.report import cube
from mstrio.connection import Connection
import openpyxl
import pandas as pd
import json



i_cube=cube()
base_url="http://85.214.60.83:8080/MicroStrategyLibrary"

path="D:\\shared_drive\\Python\\mstr_robotics\\config\\user_d.json"

with open(path, 'r') as file:
    user_d = json.load(file)

username=user_d["username"]
password=user_d["password"]
project_id="B7CA92F04B9FAE8D941C3E9B7E0CD754"
folder_id="D031653F449C1A2F9B6DA38052B7A002"

conn = Connection(base_url=base_url,username=username,
                  password=password,project_id=project_id)
conn.headers['Content-type'] = "application/json"
# Out:
# Connection to MicroStrategy Intelligence Server has been established.

# %%
demo_change_cube_name="demo_change_cube1"
demo_change_cube_id=None #"20D7132D4BA0B69A49ABE6837A0926CF"
employee = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Howy'],
    'Age': [25, 30, 35, 35],
    'City': ['New York', 'Los Angeles', 'Chicago',"Wiesloch"],
    'Country': ['US', 'US', 'US',"Baden"]
}


demo_df = pd.DataFrame(employee)

demo_d_l=[{"df":demo_df,"tbl_name":"demo_df", "update_policy":"Replace"}]
i_cube.upload_cube_mult_table(conn=conn,tbl_upd_dict=demo_d_l,mtdi_id=demo_change_cube_id 
                              , cube_name=demo_change_cube_name,folder_id=folder_id,force=False)
# Out:
# Folder object named: 'PxCD' with ID: 'D031653F449C1A2F9B6DA38052B7A002'
# Created super cube 'demo_change_cube1' with ID: '14718A26451F5423CD33598F2D0F98F3'.
# Uploading 1/1: 100%|██████████| 1/1 [00:00<00:00, 25.00it/s, rows=4]
# Super cube 'demo_change_cube1' published successfully.
# '14718A26451F5423CD33598F2D0F98F3'

# %%
file="D:\\shared_drive\\mstr_out\\demo_df.xlsx"
demo_df.to_excel(file, index=False)

# %%
cube_id="1F0C564A40101C08ABF602AAB81B2324"
df = i_cube.quick_query_cube(conn, cube_id=cube_id, attribute_l=["C307FDCF47962BAF2A67389A0B2544C6"], metric_l=[],
                                              attr_elements=None)
df
# Out:
# OlapCube object named: 'obj_prp_rel' with ID: '1F0C564A40101C08ABF602AAB81B2324'
# ...
#                                         base_url
# 0  http://85.214.60.83:8080/MicroStrategyLibrary
