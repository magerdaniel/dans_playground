# %% [markdown]
# # Create Migration Packages

# %% [markdown]
# ### import libraries

# %%
from mstr_robotics.select_mig_objects import bld_mig_content,get_change_log
from mstr_robotics.mstr_classes import md_searches, get_conn,mstr_global
from mstr_robotics.report import cube
from mstrio.types import ObjectTypes
from mstr_robotics._mod_prj_obj import bld_short_cuts
from mstr_robotics.migrate import migration
import pandas as pd
import openpyxl
import json
i_get_conn = get_conn

mig_rep= get_change_log()
mig_search= md_searches()
mig_short_cut= bld_short_cuts()
i_mstr_global=mstr_global()
i_bld_mig_content=bld_mig_content()
i_cube= cube()

#open parameter files
with open('D:\\shared_drive\\Python\\mstr_robotics\\mstr_robotics\\user_d.json', 'r') as openfile:
    user_d = json.load(openfile)

#set user credentials and open a connection to the i-server
username = user_d["username"]
password =user_d["password"]
server="85.214.60.83"
port="8080"
cube_upload_param={}

base_url= "http://" + server + ":" + port + "/MicroStrategyLibrary/api"
conn=i_get_conn(base_url=base_url,username=username,password=password)
# Out:
# Connection to MicroStrategy Intelligence Server has been established.
# No project selected.

# %% [markdown]
# ## load objects to dicts

# %% [markdown]
# ### from shortcut folder

# %%
project_id="B7CA92F04B9FAE8D941C3E9B7E0CD754"
conn.select_project(project_id)
short_cut_folder_id = "F46A9A704812AA87B6E1DA891612DEFB"
obj_l=i_mstr_global.get_folder_obj_l(conn=conn,folder_id=short_cut_folder_id)
mig_obj_l=i_bld_mig_content.from_folder(fold_short_cut_l=obj_l)
mig_obj_l
# Out:
# Folder object named: 'short_cuts' with ID: 'F46A9A704812AA87B6E1DA891612DEFB'
# [{'id': 'D4B747A64C2060963EF228B688DB13B7',
#   'type': 12,
#   'action': 'FORCE_REPLACE',
#   'include_dependents': False},
#  {'id': '4CC0901E466B1209A830F5B23C2CBEB5',
#   'type': 12,
#   'action': 'FORCE_REPLACE',
#   'include_dependents': False},
#  {'id': '7A4ABE9111D5AC6FC000D98A4CC5F24F',
#   'type': 13,
#   'action': 'FORCE_REPLACE',
#   'include_dependents': False},
#  {'id': '8D679D3811D3E4981000E787EC6DE8A4',
#   'type': 12,
#   'action': 'FORCE_REPLACE',
#   'include_dependents': False},
#  {'id': '9CD315C64948F9FE70063D9F394900A8',
#   'type': 8,
#   'action': 'FORCE_REPLACE',
#   'include_dependents': False},
#  {'id': '1B36FBB744F22223017CBD995B22693A',
#   'type': 1,
#   'action': 'FORCE_REPLACE',
#   'include_dependents': False},
#  {'id': 'D4D74D81478E5BE793335F970ABDCB81',
#   'type': 10,
#   'action': 'FORCE_REPLACE',
#   'include_dependents': False},
# ...

# %% [markdown]
# ### from excel

# %%
#load excel and check columns
excel_file="D:\shared_drive\MarksData.xlsx"
short_cut_df=pd.read_excel(excel_file)
short_cut_df.keys()

# %%
key_col_d={"id":"Object@GUID"
           ,"type":"OBJECT_TYPE_ID"
          }
action="FORCE_REPLACE"
include_dependents=False
mig_obj_l=[]
for index,obj in short_cut_df.iterrows():
    obj_d={}
    obj_d["id"] = obj[key_col_d["id"]]
    obj_d["type"] = obj[key_col_d["type"]]
    obj_d["action"] = action
    obj_d["include_dependents"] = include_dependents
    mig_obj_l.append(obj_d.copy())
mig_l

# %% [markdown]
# ### build default package

# %%
path="D:\\shared_drive\\OM_Packages\\"
name="finally.mmp"
file_name=path+name
file_name
# Out:
# 'D:\\shared_drive\\OM_Packages\\finally.mmp'

# %%
i_migration=migration()
mig_obj_l=i_migration.clean_dbl_obj(mig_obj_l=mig_obj_l)
mig_obj_l
# Out:
# [{'action': 'FORCE_REPLACE',
#   'id': 'EC01D58741E70400ED4DDEAF33D40D1C',
#   'include_dependents': False,
#   'type': 8},
#  {'action': 'FORCE_REPLACE',
#   'id': 'F30CB66411D5AC5FC000D98A4CC5F24F',
#   'include_dependents': False,
#   'type': 13},
#  {'action': 'FORCE_REPLACE',
#   'id': '4270FECF4EC4351208B44D8D8BD756A9',
#   'include_dependents': False,
#   'type': 10},
#  {'action': 'FORCE_REPLACE',
#   'id': 'AE0ADBBE4F0A0D0034D884981D478E4E',
#   'include_dependents': False,
#   'type': 55},
#  {'action': 'FORCE_REPLACE',
#   'id': 'A58D5630483A8CA5E5D77FA443E791A7',
#   'include_dependents': False,
#   'type': 10},
#  {'action': 'FORCE_REPLACE',
#   'id': '6EA98A164E62D247C14B3EBFA4866411',
#   'include_dependents': False,
#   'type': 13},
#  {'action': 'FORCE_REPLACE',
#   'id': '1B57B66F462F36A50CDA6D8986B848D0',
#   'include_dependents': False,
#   'type': 10},
#  {'action': 'FORCE_REPLACE',
#   'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#   'include_dependents': False,
# ...

# %%
tuple_l = set(tuple(sorted(d.items())) for d in mig_obj_l)

# Convert tuples back to dictionaries
unique_dict_l = [dict(t) for t in tuple_l]

unique_dict_l
# Out:
# [{'action': 'FORCE_REPLACE',
#   'id': 'EC01D58741E70400ED4DDEAF33D40D1C',
#   'include_dependents': False,
#   'type': 8},
#  {'action': 'FORCE_REPLACE',
#   'id': '4270FECF4EC4351208B44D8D8BD756A9',
#   'include_dependents': False,
#   'type': 10},
#  {'action': 'FORCE_REPLACE',
#   'id': 'F30CB66411D5AC5FC000D98A4CC5F24F',
#   'include_dependents': False,
#   'type': 13},
#  {'action': 'FORCE_REPLACE',
#   'id': 'AE0ADBBE4F0A0D0034D884981D478E4E',
#   'include_dependents': False,
#   'type': 55},
#  {'action': 'FORCE_REPLACE',
#   'id': 'A58D5630483A8CA5E5D77FA443E791A7',
#   'include_dependents': False,
#   'type': 10},
#  {'action': 'FORCE_REPLACE',
#   'id': '6EA98A164E62D247C14B3EBFA4866411',
#   'include_dependents': False,
#   'type': 13},
#  {'action': 'FORCE_REPLACE',
#   'id': 'DF3F09244F5DFAECC77BFAB04F4B62D4',
#   'include_dependents': False,
#   'type': 10},
#  {'action': 'FORCE_REPLACE',
#   'id': '4CC0901E466B1209A830F5B23C2CBEB5',
#   'include_dependents': False,
# ...

# %%
#i_migration=migration()

create_mig=i_migration.create_default_pack(file_name=file_name,source_conn=conn,mig_obj_l=mig_obj_l)
# Out:
# Created package with ID: 'QjdDQTkyRjA0QjlGQUU4RDk0MUMzRTlCN0UwQ0Q3NTQ6MDJDNTcwNTc0RDhGNkJFNDUzOERDMUFGOTZEODQ4NTM='
# Downloaded binary of a package with ID: 'QjdDQTkyRjA0QjlGQUU4RDk0MUMzRTlCN0UwQ0Q3NTQ6MDJDNTcwNTc0RDhGNkJFNDUzOERDMUFGOTZEODQ4NTM='
# Package / package undo binary created at:D:\shared_drive\OM_Packages\finally.mmp

# %%
i_migrate=migration()
target_conn=conn
migrate_mig=i_migrate.migrate_default_pack(file_name,target_conn=target_conn)

# %%
#define a Platform Analytics (PA) report & prompts as source of the change logs
#You also find this in the MD.
#You can access to the md using a free form SQL Report
#

pa_project_id="01770E1B45A0B84E88E5748B465719AD"
ch_conn=i_get_conn(base_url=base_url,username=username,password=password)

ch_conn.select_project(pa_project_id)

change_log_report={"chg_log_rep_proj_id":"01770E1B45A0B84E88E5748B465719AD"
               ,"chg_log_report_id":"3D2EA48442A562773B52718BADB709D4"
               ,"chg_log_from_date_prompt_id":"7FDFC8F441AF97399F792C8E8FC4CA91"
               ,"chg_log_to_date_prompt_id":"AF158BC0432DC097838F7D9017AC9CBA"
               ,"chg_log_proj_prompt_id":"1627FE2E46F1C7F2B7BB4B9CF5EE8F29"
               }

# %% [markdown]
# ## set project and timeframe to read out changes & get a dataframe

# %%
#execute the report to fetch the change logs. 
chg_log_from_date = "2023-02-10"
chg_log_to_date = "2023-09-11"
project_id="B7CA92F04B9FAE8D941C3E9B7E0CD754"

conn.select_project(project_id)

#export the to a pandas dataframe
ch_df=mig_rep.get_mig_obj_logs(conn=conn,ch_conn=ch_conn,change_log_report=change_log_report,
                               project_id=project_id,from_date=chg_log_from_date,
                               to_date=chg_log_to_date,chg_log_source="pa")
#from there you can:
#    1)cube the data
#    2)create short cuts to the objects
#    3)export them to excel

# %% [markdown]
# ## load dataframe to a cube

# %%
cube_name="Change logs"
migration_folder_id="9D3969374E91C4D795F16DA25181A8C4"
mtdi_id=None

ch_upd_d_l=[{"df":ch_df,"tbl_name":"ch_df", "update_policy":"Replace"}]

i_cube.upload_cube_mult_table(conn=conn,tbl_upd_dict=ch_upd_d_l, cube_name=cube_name,folder_id=migration_folder_id,force=True)

# %% [markdown]
# ## Transform the data i.e. to build meaning full short cuts

# %%
#the data frames can be passed over to Python functions
short_cut_df= mig_rep.bld_change_log_shortcut_df(conn=conn,change_log_df=ch_df)
short_cut_df

# %% [markdown]
# ##build the short cuts the as defined in the previous step

# %%
short_cut_proj_id = "B7CA92F04B9FAE8D941C3E9B7E0CD754" 
short_cut_folder_id = "F46A9A704812AA87B6E1DA891612DEFB"
migration_folder_id = "9D3969374E91C4D795F16DA25181A8C4"
mtdi_id = "5FE4766B4E0217E188E9959DFF2EAD82" 

mig_short_cut.run_short_cut_build(conn=conn,project_id=short_cut_proj_id,
                                  short_cut_df=short_cut_df,folder_id=short_cut_folder_id)

# %% [markdown]
# ## last but not least, export it to excel

# %%
short_cut_df.to_excel("D:\shared_drive\MarksData.xlsx")

# %%
ch_df
