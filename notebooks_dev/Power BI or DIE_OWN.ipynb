# %%
import requests
import re
import pandas as pd
import json
from mstrio.connection import Connection
from mstr_robotics import report
from mstr_robotics._connectors import mstr_api
i_rep=report.rep()
i_mstr_api=mstr_api()

path="D:\\shared_drive\\Python\\mstr_robotics\\mstr_robotics\\user_d.json"

with open(path, 'r') as file:
    user_d = json.load(file)

# %%
base_url="http://85.214.60.83:8080/MicroStrategyLibrary"
username=user_d["username"]
password=user_d["password"]

project_id="B7CA92F04B9FAE8D941C3E9B7E0CD754"
demo_report_id="C4FF6CF34933EF4B3B1D798D02D4FB36"


#conn=get_conn(base_url,project_id=project_id,username=username,password=password)
conn = Connection(base_url=base_url,username=username,password=password,project_id=project_id)
conn.headers['Content-type'] = "application/json"
# Out:
# Connection to MicroStrategy Intelligence Server has been established.

# %%
instance_id=i_rep.open_Instance(conn=conn, report_id=demo_report_id)
pa_rep_df=i_rep.report_df(conn=conn, report_id=demo_report_id, instance_id=instance_id)
pa_rep_df
# Out:
# Report object named: 'MSTR Security Demo' with ID: 'C4FF6CF34933EF4B3B1D798D02D4FB36'
#        Category     Region    Call Center Employee@Last Name  \
# 0         Books    Central      Milwaukee               Gale
# 1         Books    Central      Milwaukee           Torrison
# 2         Books    Central      Milwaukee           Zemlicka
# 3         Books    Central          Fargo          Ellerkamp
# 4         Books  Northwest  San Francisco             Becker
# 5         Books  Northwest  San Francisco               Hall
# 6         Books  Northwest        Seattle              Gedot
# 7   Electronics    Central      Milwaukee               Gale
# 8   Electronics    Central      Milwaukee           Torrison
# 9   Electronics    Central      Milwaukee           Zemlicka
# 10  Electronics    Central          Fargo          Ellerkamp
# 11  Electronics  Northwest  San Francisco             Becker
# 12  Electronics  Northwest  San Francisco               Hall
# ...

# %%
#export to excel
excel_file="D:\\shared_drive\\mstr_out\\PxCD_demo.xlsx"
pa_rep_df.to_excel(excel_file, index=False)

# %%
SQL_resp=i_mstr_api.get_report_sql(conn=conn,report_id=demo_report_id,instance_id=instance_id)
sql_t=SQL_resp.json()
query=sql_t["sqlStatement"]

readable_query = query.replace('\t', '    ').replace('\n', '\n')

# Print the formatted query
print(readable_query)
# Out:
# select    "a13"."category_id" AS "category_id",
#     max("a16"."category_desc") AS "category_desc0",
#     "a15"."region_id" AS "region_id",
#     max("a17"."region_name") AS "region_name0",
#     "a14"."call_ctr_id" AS "call_ctr_id",
#     max("a15"."center_name") AS "center_name",
#     "a11"."emp_id" AS "emp_id",
#     max("a14"."emp_last_name") AS "emp_last_name",
#     max("a14"."emp_first_name") AS "emp_first_name",
#     sum("a11"."tot_dollar_sales") AS "Revenue",
#     sum("a11"."tot_cost") AS "WJXBFS1",
#     (sum("a11"."tot_dollar_sales") - sum("a11"."tot_cost")) AS "WJXBFS2"
# from    "public"."item_emp_sls"    "a11"
#     join    "public"."lu_item"    "a12"
#       on     ("a11"."item_id" = "a12"."item_id")
#     join    "public"."lu_subcateg"    "a13"
#       on     ("a12"."subcat_id" = "a13"."subcat_id")
#     join    "public"."lu_employee"    "a14"
#       on     ("a11"."emp_id" = "a14"."emp_id")
#     join    "public"."lu_call_ctr"    "a15"
# ...

# %% [markdown]
# ## prompts handling

# %%
report_id="B466214A4A0CE9CDCC7D07863D3FADD7"
prp_json=i_rep.get_default_prp_answ(conn, report_id)
prp_json.json()
# Out:
# []

# %%
prp_l=[{'id': 'h2;8D679D4B11D3E4981000E787EC6DE8A4'},{'id': 'h1;8D679D4B11D3E4981000E787EC6DE8A4'}]

region_prp = {"id": "38FB260A4099305D4220B485B927D84E", "type": 'ELEMENTS',"answers": prp_l}

prp_ans={"prompts": [region_prp] }

prompt_answ=json.dumps(prp_ans)
prompt_answ
# Out:
# '{"prompts": [{"id": "38FB260A4099305D4220B485B927D84E", "type": "ELEMENTS", "answers": [{"id": "h2;8D679D4B11D3E4981000E787EC6DE8A4"}, {"id": "h1;8D679D4B11D3E4981000E787EC6DE8A4"}]}]}'

# %%
#handle Prompts
instance_id=i_rep.open_Instance(conn=conn, report_id=report_id)
ans=i_rep.set_inst_prompt_ans(conn=conn, report_id=report_id, instance_id=instance_id, prompt_answ=prompt_answ)
df=i_rep.rep_to_dataframe(conn=conn, report_id=report_id, instance_id=instance_id)
df
# Out:
#     Region@DESC Region@ID Call_Center@DESC     Revenue
# 0  Mid-Atlantic         2   Washington, DC  3135282.90
# 1  Mid-Atlantic         2       Charleston  1317332.15
# 2     Northeast         1           Boston  1487936.20
# 3     Northeast         1         New York  7066478.35
