# %% [markdown]
# ### set up of the Jupyter Notebook
# set up is done by the developer
# of the underling python modules

# %%
import pandas as pd
import json
from mstr_robotics import regam
from mstr_robotics._helper import msic
from mstr_robotics.mstr_classes import get_conn,md_searches
from mstr_robotics.report import prompts
#from mstr_robotics.dossier import dossiers

#from mstr_robotics._pa_etl import parse_pa #, run_prp_ans_bld
i_test=regam.test_exe()
#i_parse_pa = parse_pa()
#i_dossiers=dossiers()
i_msic=msic()
i_prompts=prompts()
i_get_conn=get_conn
i_regam=regam.regam()
i_md_search=md_searches()
i_regam_jobs=regam.regam_jobs()
with open('D:\\shared_drive\\Python\\mstr_robotics\\mstr_robotics\\user_d.json', 'r') as openfile:
    user_d = json.load(openfile)
with open('D:\\shared_drive\\Python\\mstr_robotics\\mstr_robotics\\MSTR_robotics_config.json', 'r') as openfile:
    MSTR_robotics_config_d = json.load(openfile)

    
username =user_d["username"]
password = user_d["password"]

server = MSTR_robotics_config_d["mstr_env"][0]["server"]
port = MSTR_robotics_config_d["mstr_env"][0]["port"]
base_url = "http://" + server + ":" + port + "/MicroStrategyLibrary/api"

pa_project_id = MSTR_robotics_config_d["pa_env"]["pa_project_id"]
pa_report_id = MSTR_robotics_config_d["pa_env"]["pa_report_id"]
pa_conn=i_get_conn(base_url=base_url,project_id=pa_project_id,username=username,password=password)
pa_conn.select_project(pa_project_id)


conn=i_get_conn(base_url=base_url,username=username,password=password)
project_id ="B7CA92F04B9FAE8D941C3E9B7E0CD754"
conn.select_project(project_id)
# Out:
# Connection to MicroStrategy Intelligence Server has been established.
# Connection to MicroStrategy Intelligence Server has been established.
# No project selected.

# %% [markdown]
# ### Define your environment
# I prefer config files, but you also can write the GUID directly.

# %%
conn.select_project(project_id)
test_project_d=i_msic.get_dict_with_id_in_l(dict_l= MSTR_robotics_config_d["REGAM_project"],search_l=[project_id],
                             key="project_id")[0]
project_id=test_project_d["project_id"]
REGAM_cube_folder_id = "9981CB214C79D75EC342A781539A4E5A"
#hier_att_cube_id =  test_project_d["hier_att_cube_id"]
hier_att_cube_id = "C38006F64A7C63368626FB82535FD1DC"
REGAM_log_file= MSTR_robotics_config_d["REGAM_log_file"]
pa_report_id="31FF880045D230BE04C209A42C108B24"

# %% [markdown]
# ### define the the test
# prepare some masterdata
# generate the prompt answers JSONs for re-play

# %%
#search for all Dossiers under the REGAM folder
dossier_l=[]
regam_folder_id="65984E814DA3C4721FF4E3B83DDF4F4F"
search_dossier_l=i_md_search.search_for_type_l( conn=pa_conn, input_type="type_l", obj_l="55",root_folder_id=regam_folder_id)
for doss in search_dossier_l:
    dossier_l.append(doss["id"])
print(dossier_l)
#parse the structure of a dossier to and display chapter, pages & visualizations
doss_viz_df=i_dossiers.doss_hier_to_df(conn=pa_conn,dossier_l=dossier_l)
doss_viz_df

# %%
filtered_df = doss_viz_df[doss_viz_df['visual_key']=="W65"]
#filtered_df = filtered_df[filtered_df['dossier_id']=="5F33A34742F786821D57019B32EF60D7"]
filtered_df

# %%
att_exp_ans_l=i_regam_jobs.run_read_out_job_vis(conn=pa_conn,filtered_df=filtered_df)
prompt_id="948E03AF475DF4E4B37BF8B404FB4D80"
prp_d=i_prompts.bld_expr_prp_answ(prompt_id, att_exp_ans_l)
prompt_answ=i_prompts.frame_prp(prp_ans=[prp_d])
pa_conn.select_project(pa_project_id)
pa_raw_data_df=i_regam.fetch_pa_rep_jobs(pa_conn=pa_conn, pa_report_id=pa_report_id,prompt_answ=prompt_answ)

# %%
search_dossier_l

# %%
#get the jobs stored in a static report for this use case.
pa_report_id="31FF880045D230BE04C209A42C108B24"
pa_conn.select_project(pa_project_id)
pa_raw_data_df=i_regam.fetch_pa_rep_jobs(pa_conn=pa_conn, pa_report_id=pa_report_id)
#identify projects and prompts
#pa_prp_id_l = i_parse_pa.get_pa_prp_id_l(get_pa_raw_data_df=pa_raw_data_df)
pa_raw_data_df
# Out:
#        Date@ID           Session@ID Job@ID            Project@Name  \
# 0    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 1    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 2    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 3    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 4    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 5    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 6    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 7    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 8    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 9    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 10   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# 11   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# 12   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# ...

# %%
hier_att_cube_id

# %%
#to parse attribute expresion prompts
#we need GUID. We can fetch this from the endpoint hierarchies
#the result bis stored in a cube
conn.select_project(project_id)
hier_att_df=i_regam.refresh_hier_att_cube(conn=conn,REGAM_cube_folder_id=REGAM_cube_folder_id,proj_prp_hier_l=None,
                      hier_att_cube_id=hier_att_cube_id)
# Out:
# WWWW [{'project_id': 'B7CA92F04B9FAE8D941C3E9B7E0CD754', 'id': 'FD107ADDE8A948AE80F794A288FA70F4', 'name': 'System Hierarchy', 'type': 14, 'subtype': 3584, 'dateCreated': '2010-06-11T18:38:55.000+0000', 'dateModified': '2024-11-12T06:25:38.000+0000', 'version': '13CDC5454BD1EE04EBEE3C8588661210', 'owner_id': '54F3D26011D2896560009A8E67019608', 'owner_name': 'Administrator'}]
#                            project_id                           hier_id  \
# 0    B7CA92F04B9FAE8D941C3E9B7E0CD754  FD107ADDE8A948AE80F794A288FA70F4
# 1    B7CA92F04B9FAE8D941C3E9B7E0CD754  FD107ADDE8A948AE80F794A288FA70F4
# 2    B7CA92F04B9FAE8D941C3E9B7E0CD754  FD107ADDE8A948AE80F794A288FA70F4
# 3    B7CA92F04B9FAE8D941C3E9B7E0CD754  FD107ADDE8A948AE80F794A288FA70F4
# 4    B7CA92F04B9FAE8D941C3E9B7E0CD754  FD107ADDE8A948AE80F794A288FA70F4
# 5    B7CA92F04B9FAE8D941C3E9B7E0CD754  FD107ADDE8A948AE80F794A288FA70F4
# 6    B7CA92F04B9FAE8D941C3E9B7E0CD754  FD107ADDE8A948AE80F794A288FA70F4
# ...

# %%
#load the cube hierarchy / Attribute information into a dataframe 
hier_att_df=i_regam.load_hier_att_df(conn=conn,hier_att_cube_id=hier_att_cube_id)
hier_att_df
# Out:
# _Cube object named: 'System hier_att' with ID: 'C38006F64A7C63368626FB82535FD1DC'
#             hier_name                       att_form_id  \
# 0    System Hierarchy  035E890A4157E9828414E8A0E13E2998
# 1    System Hierarchy  09519087400FA5D820319D91CB1D31D6
# 2    System Hierarchy  15630A7741292F084B0DA5BE4F665DC2
# 3    System Hierarchy  1AD216D2479DAE06A3DA5FAAD1C43581
# 4    System Hierarchy  1ADFF4B444AD6AB288828EBA9BB9395C
# 5    System Hierarchy  1EEA54FB405CFE549065D493EA201D19
# 6    System Hierarchy  275054184F8E4BCFD5C6F7A1D981EE52
# 7    System Hierarchy  2FCF90264BCCA73839D2489007A90013
# 8    System Hierarchy  300639E64DF80E547D7DC0A2CFC3D11B
# 9    System Hierarchy  3A6E8E08430A1B05053247BC73ACDD3A
# 10   System Hierarchy  412A181E4759B159187EFDBC8D241482
# 11   System Hierarchy  45C11FA478E745FEA08D781CEA190FE5
# 12   System Hierarchy  45C11FA478E745FEA08D781CEA190FE5
# 13   System Hierarchy  45C11FA478E745FEA08D781CEA190FE5
# ...

# %%
pa_raw_data_df=i_regam.fetch_pa_rep_jobs(pa_conn=pa_conn,  pa_report_id=pa_report_id)
pa_raw_data_df
# Out:
#        Date@ID           Session@ID Job@ID            Project@Name  \
# 0    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 1    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 2    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 3    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 4    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 5    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 6    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 7    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 8    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 9    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 10   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# 11   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# 12   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# ...

# %%
all_jobs_prp_ans_JSON_d=i_regam.run_bld_job_prp_JSON(conn,pa_raw_data_df=pa_raw_data_df,hier_att_df=hier_att_df)
all_jobs_prp_ans_JSON_d
# Out:
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# []
# string indices must be integers, not 'str'
# Error getting report 63342EDF4FBEFF4CD4CC008C4AA58661 contents.
# I-Server Error ERR004, The object does not exist in the metadata.
# Ticket ID: b85d530a7bba44d78415d6948ed68b29
# The object does not exist in the metadata.; code: 'ERR004', ticket_id: 'b85d530a7bba44d78415d6948ed68b29'
# Error getting report 63342EDF4FBEFF4CD4CC008C4AA58661 contents.
# I-Server Error ERR004, The object does not exist in the metadata.
# Ticket ID: fe5b23a2ffd24f1f8e90dd661a503b85
# ...

# %% [markdown]
# ### run the test

# %%
i_test.run_test_exe(conn=conn,all_jobs_prp_ans_JSON_l=all_jobs_prp_ans_JSON_d["all_jobs_prp_ans_JSON_l"])

# %%
REGAM_log_file
# Out:
# 'D:\\shared_drive\\Python\\mstr_robotics\\REGAM_logs\\'

# %%
hier_att_df
# Out:
# 'C38006F64A7C63368626FB82535FD1DC'

# %%
pa_raw_data_df
# Out:
#        Date@ID           Session@ID Job@ID            Project@Name  \
# 0    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 1    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 2    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 3    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 4    7/30/2024  7224051206363025408     10  MicroStrategy Tutorial
# 5    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 6    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 7    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 8    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 9    7/30/2024  7224051206363025408     11  MicroStrategy Tutorial
# 10   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# 11   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# 12   7/30/2024  7224051206363025408     12  MicroStrategy Tutorial
# ...
